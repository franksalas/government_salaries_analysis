# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import glob, os
import numpy as np
import matplotlib.pyplot as plt
import datetime  as dt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# # Data directory

# %%
location = 'state'
year = '2014'

# %%
data_directory = os.path.join( '..','data','clean_data','{}/{}/'.format(location,year))

# %%
df = pd.read_csv(data_directory+'/state_2014.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148403 entries, 0 to 148402
# Data columns (total 10 columns):
# name             148403 non-null object
# agency           148403 non-null int64
# agency_name      148403 non-null object
# class_title      148403 non-null object
# ethnicity        148403 non-null object
# gender           148403 non-null object
# employee_type    148403 non-null object
# annual_salary    148403 non-null float64
# state_number     148403 non-null int64
# tenure           148403 non-null int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
df.head()
# Out:
#                                name  agency agency_name  \
# 0  S.Acosta                             101      Senate
# 1  K.Ahlhorn                            101      Senate
# 2  E.Akpan                              101      Senate
# 3  S.Albright                           101      Senate
# 4  L.Alexander                          101      Senate
#
#                    class_title ethnicity  gender employee_type  annual_salary  \
# 0  Leg. Official/Administrator  hispanic  female           URP        51000.0
# 1     Legislative Professional     white    male           URF        34200.0
# 2  Leg. Official/Administrator     black  female           URF        51600.0
# 3  Leg. Official/Administrator     white    male           URP        85800.0
# 4  Leg. Official/Administrator     white  female           URF        66000.0
#
#    state_number  tenure
# 0         59341      10
# 1        341347       1
# 2          6093       9
# 3         57927       7
# 4         11289       1

# %% [markdown]
# ## EDA

# %%
# group by agency_name

grp_agency = df.groupby('agency_name')

# %%
grp_agency['annual_salary',].median()
# Out:
#                                                     annual_salary
# agency_name
# Alcoholic Beverage Commission                            47649.00
# Board Of Architectural Examiners                         65086.92
# Board Of Chiropractic Examiners                          40599.96
# Board Of Dental Examiners                                42600.00
# Board Of Examiners Of Psychologists                      37445.34
# Board Of Medical Examiners                               40599.96
# Board Of Nurse Examiners                                 46800.00
# Board Of Pharmacy                                        44856.00
# Board Of Plumbing Examiners                              43050.00
# Board Of Professional Geoscientists                      57999.96
# Board Of Professional Land Surveying                     41161.44
# Board Of Public Accountancy                              43481.28
# Board Of Veterinary Medical Examiners                    45062.04
# ...

# %%
df.ethnicity.value_counts().plot('barh')

# %%
df.ethnicity.value_counts().plot('box')

# %%
df.ethnicity.unique()

# %%
sns.distplot(df.tenure,hist=True)
